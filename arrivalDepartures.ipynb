# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Carica il dataset
df = pd.read_csv('datasets/ArrivalDepartures.csv')

# Lista dei paesi da visualizzare
countries = ['Italy', 'United Kingdom', 'Germany', 'United States', 'France']

# Crea una lista degli anni dal 2000 al 2020
years = [f"{year} [YR{year}]" for year in range(2000, 2021)]
numeric_years = list(range(2000, 2021))  # Lista degli anni come numeri

# Colori pastello e saturi per l'Italia
colors = {
    'arrivals': {'default': '#93c9f7', 'Italy': '#1f78b4'},
    'departures': {'default': '#ffb380', 'Italy': '#ff4500'}
}

# Funzione per formattare l'asse verticale
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'

# Calcola il valore massimo tra arrivi e partenze per fissare l'intervallo delle y
max_value = 0
for country in countries:
    country_data = df[df['Country Name'] == country]
    arrivals = pd.to_numeric(country_data[years].iloc[0], errors='coerce') \
               .interpolate(method='linear', limit_direction='both').values
    departures = pd.to_numeric(country_data[years].iloc[1], errors='coerce') \
                 .interpolate(method='linear', limit_direction='both').values
    max_value = max(max_value, max(arrivals), max(departures))

# %%
country = 'Italy'
country_data = df[df['Country Name'] == country]

arrivals = pd.to_numeric(country_data[years].iloc[0], errors='coerce') \
           .interpolate(method='linear', limit_direction='both').values
departures = pd.to_numeric(country_data[years].iloc[1], errors='coerce') \
             .interpolate(method='linear', limit_direction='both').values

x = np.arange(len(numeric_years))
width = 0.4

color_arrivals = colors['arrivals']['Italy']
color_departures = colors['departures']['Italy']

plt.figure(figsize=(12, 4))
plt.bar(x - width / 2, arrivals, width=width, color=color_arrivals, alpha=0.8, label='Arrivi')
plt.bar(x + width / 2, departures, width=width, color=color_departures, alpha=0.8, label='Partenze')

plt.title(f'{country}', fontsize=12)
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions_formatter))
plt.ylim(0, 110e6)
plt.xticks(x, numeric_years, rotation=45, fontsize=10)
plt.ylabel('Numero di Turisti', fontsize=10)
plt.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %%
country = 'United Kingdom'
country_data = df[df['Country Name'] == country]

arrivals = pd.to_numeric(country_data[years].iloc[0], errors='coerce') \
           .interpolate(method='linear', limit_direction='both').values
departures = pd.to_numeric(country_data[years].iloc[1], errors='coerce') \
             .interpolate(method='linear', limit_direction='both').values

x = np.arange(len(numeric_years))
width = 0.4

color_arrivals = colors['arrivals']['default']
color_departures = colors['departures']['default']

plt.figure(figsize=(12, 4))
plt.bar(x - width / 2, arrivals, width=width, color=color_arrivals, alpha=0.8, label='Arrivi')
plt.bar(x + width / 2, departures, width=width, color=color_departures, alpha=0.8, label='Partenze')

plt.title(f'{country}', fontsize=12)
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions_formatter))
plt.ylim(0, 110e6)
plt.xticks(x, numeric_years, rotation=45, fontsize=10)
plt.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %%
country = 'Germany'
country_data = df[df['Country Name'] == country]

arrivals = pd.to_numeric(country_data[years].iloc[0], errors='coerce') \
           .interpolate(method='linear', limit_direction='both').values
departures = pd.to_numeric(country_data[years].iloc[1], errors='coerce') \
             .interpolate(method='linear', limit_direction='both').values

x = np.arange(len(numeric_years))
width = 0.4

color_arrivals = colors['arrivals']['default']
color_departures = colors['departures']['default']

plt.figure(figsize=(12, 4))
plt.bar(x - width / 2, arrivals, width=width, color=color_arrivals, alpha=0.8, label='Arrivi')
plt.bar(x + width / 2, departures, width=width, color=color_departures, alpha=0.8, label='Partenze')

plt.title(f'{country}', fontsize=12)
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions_formatter))
plt.ylim(0, 110e6)
plt.xticks(x, numeric_years, rotation=45, fontsize=10)
plt.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %%
country = 'United States'
country_data = df[df['Country Name'] == country]

arrivals = pd.to_numeric(country_data[years].iloc[0], errors='coerce') \
           .interpolate(method='linear', limit_direction='both').values
departures = pd.to_numeric(country_data[years].iloc[1], errors='coerce') \
             .interpolate(method='linear', limit_direction='both').values

x = np.arange(len(numeric_years))
width = 0.4

color_arrivals = colors['arrivals']['default']
color_departures = colors['departures']['default']

plt.figure(figsize=(12, 4))
plt.bar(x - width / 2, arrivals, width=width, color=color_arrivals, alpha=0.8, label='Arrivi')
plt.bar(x + width / 2, departures, width=width, color=color_departures, alpha=0.8, label='Partenze')

plt.title(f'{country}', fontsize=12)
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions_formatter))
plt.ylim(0, max_value * 1.1)
plt.xticks(x, numeric_years, rotation=45, fontsize=10)
plt.legend(fontsize=10)
plt.tight_layout()
plt.show()

# %%
country = 'France'
country_data = df[df['Country Name'] == country]

arrivals = pd.to_numeric(country_data[years].iloc[0], errors='coerce') \
           .interpolate(method='linear', limit_direction='both').values
departures = pd.to_numeric(country_data[years].iloc[1], errors='coerce') \
             .interpolate(method='linear', limit_direction='both').values

x = np.arange(len(numeric_years))
width = 0.4

color_arrivals = colors['arrivals']['default']
color_departures = colors['departures']['default']

plt.figure(figsize=(12, 4))
plt.bar(x - width / 2, arrivals, width=width, color=color_arrivals, alpha=0.8, label='Arrivi')
plt.bar(x + width / 2, departures, width=width, color=color_departures, alpha=0.8, label='Partenze')

plt.title(f'{country}', fontsize=12)
plt.gca().yaxis.set_major_formatter(FuncFormatter(millions_formatter))
plt.ylim(0, max_value * 1.1)
plt.xticks(x, numeric_years, rotation=45, fontsize=10)
plt.legend(fontsize=10)
plt.tight_layout()
plt.show()
